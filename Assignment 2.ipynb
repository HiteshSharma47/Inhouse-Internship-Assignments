# %% [markdown]
# # Q.1) Practice : Dictionary , Tuple , Set

# %%
d = {'A':'Messi','B':'Ronaldo','C':'Neymar'}
print("Dictionary : ",d)
print("\n Access Elements by Key : ", d['A'])
e = {'A':'Messi','B':'Ronaldo','C':'Neymar','D':{1:'fifa',2:'ucl',3:'club'}}
print("\n Nested dictionary : ",e)
print("\n Access in nested dictionary : ",e['D'][1])
d['D']='Mbappe';
print("\n Adding Elements : ",d)
del d['D']
print("\n Delete Element : ",d)
a = {1: "Python", 2: "Java", 3: "C++", 4: "Dart"}
b = a.copy()
print("\n using a.copy() : " , b)
print("\n using a.items() : " , a.items())
print("\n using a.keys() : " , a.keys())
print("\n using a.values() : " , a.values())
a.update({5: "C"})
print("\n using a.update(dict) : " , a)
a.pop(3)
print("\n using pop(key) : " , a)
a.popitem()
print("\n using a.popitem() : " , a)
a.clear()
print("\n using a.clear() : " , a)

t1 = (10,20,30,40)
print("\nTuple : " , t1)
print("\n Iterate Tuple:")
for x in t1:
    print(x,end=" ")

t2 =(50,60,70,80)
print("\n\n Concatination Of Tuple : ",t1 + t2)
t3 = (1,2)
t4 = ('A','B')
t5 = (t3,t4)
print("\n Nesting Of Tuple : ",t5)
t = ('xyz',) * 3
print("\n Repetition in Tuple : ",t)
print("\n Slicing in Tuple : ", t1[0:2])
print("\n Length of tuple : ",len(t1))
l = [10,20,30]
print("\n list : ",l)
print("\n list to tuple : ",tuple(l))
x = (10, 20, 30, 40, 50)
print("\n min : ",min(x)) 
print("\n max : ",max(x)) 
print("\n count : ",x.count(30)) 
print("\n index : ",x.index(40)) 
print("\n sum : ",sum(x)) 

s = {"apple", "banana", "cherry"}
print("\nSet : ",s)
s.add("mango")
print("\n Add Elements : ",s)
s1 = {"apple", "banana", "cherry"}
s2 = {"abc", 10, 20}
print("\n Union of set : ",s1.union(s2))
s1 = {1,2,3,4}
s2 = {3,4,5,6}
print("\n Intersection of set : ",s1.intersection(s2))
print("\n Difference of set : ",s1 - s2)
print("\n s1 : ",s1)
s1.clear()
print("\n clear s1 : ",s1)
print("\n///Operations on Sets///")
s = {1,2,3,4,'apple','mango','banana'}
u = {1,2,3,4,'apple'}
print("\n key in s : ",1 in s)
print("\n key not in s : ",1 not in s)
print("\n s == u: ",s == u)
print("\n s != u : ",s != u)
print("\n s >= u : ",s >= u)
print("\n s > u : ",s > u)
print("\n s <= u : ",s <= u)
print("\n s < u : ",s < u)
print("\n s ^ u : ",s ^ u)
# Out:
# Dictionary :  {'A': 'Messi', 'B': 'Ronaldo', 'C': 'Neymar'}
#
#  Access Elements by Key :  Messi
#
#  Nested dictionary :  {'A': 'Messi', 'B': 'Ronaldo', 'C': 'Neymar', 'D': {1: 'fifa', 2: 'ucl', 3: 'club'}}
#
#  Access in nested dictionary :  fifa
#
#  Adding Elements :  {'A': 'Messi', 'B': 'Ronaldo', 'C': 'Neymar', 'D': 'Mbappe'}
#
#  Delete Element :  {'A': 'Messi', 'B': 'Ronaldo', 'C': 'Neymar'}
#
#  using a.copy() :  {1: 'Python', 2: 'Java', 3: 'C++', 4: 'Dart'}
#
#  using a.items() :  dict_items([(1, 'Python'), (2, 'Java'), (3, 'C++'), (4, 'Dart')])
#
#  using a.keys() :  dict_keys([1, 2, 3, 4])
#
#  using a.values() :  dict_values(['Python', 'Java', 'C++', 'Dart'])
#
#  using a.update(dict) :  {1: 'Python', 2: 'Java', 3: 'C++', 4: 'Dart', 5: 'C'}
#
#  using pop(key) :  {1: 'Python', 2: 'Java', 4: 'Dart', 5: 'C'}
#
#  using a.popitem() :  {1: 'Python', 2: 'Java', 4: 'Dart'}
#
#  using a.clear() :  {}
#
# Tuple :  (10, 20, 30, 40)
#
#  Iterate Tuple:
# 10 20 30 40
#
# ...

# %% [markdown]
# # Q.2) Write a function for basic math operations like add multiply substract divide and use this in your program, take 2 number input from user.

# %%
print("""Choices:
    1)Addition
    2)Subtraction
    3)Divide
    4)Multiplication
    5)Exit Simulation""")
while(True):
    c = int(input("Enter Your Choice :"))
    if c == 1:
        a = float(input("\nEnter Number 1 :"))
        b = float(input("Enter Number 2 :"))
        print(f"\n Sum of {a} and {b} is : ",a + b)
    elif c == 2:
        a = float(input("Enter Number 1 :"))
        b = float(input("Enter Number 2 :"))
        print(f"\n Subtraction of {a} and {b} is : ",a - b)
    elif c == 3:
        a = float(input("Enter Number 1 :"))
        b = float(input("Enter Number 2 :"))
        div = a / b
        print(f"\n Division of {a} and {b} is : {div:.2f}")
    elif c == 4:
        a = float(input("Enter Number 1 :"))
        b = float(input("Enter Number 2 :"))
        print(f"\n Multiplication of {a} and {b} is : ",a * b)
    elif c == 5:
        print("BYE!!")
        break
    else:
        print("Invalid Input")
# Out:
# Choices:
#     1)Addition
#     2)Subtraction
#     3)Divide
#     4)Multiplication
#     5)Exit Simulation
# Enter Your Choice : 1
#
# Enter Number 1 : 1
# Enter Number 2 : 2
#  Sum of 1.0 and 2.0 is :  3.0
# Enter Your Choice : 2
# Enter Number 1 : 3
# Enter Number 2 : 2
#  Subtraction of 3.0 and 2.0 is :  1.0
# Enter Your Choice : 3
# Enter Number 1 : 4
# Enter Number 2 : 2
#  Division of 4.0 and 2.0 is : 2.00
# Enter Your Choice : 4
# Enter Number 1 : 5
# Enter Number 2 : 5
#  Multiplication of 5.0 and 5.0 is :  25.0
# Enter Your Choice : 6
# Invalid Input
# Enter Your Choice : 5
# BYE!!

# %% [markdown]
# # 3) Write a program to check Palindrome Number
# # For example Number 12321 is a Palindrome Number, because 12321 is equal to its reverse Number 12321.
# # Steps for checking Palindrome number
# # 1. Find reverse of the given number.
# # 2. Compare that number with the reverse number.
# # 3. If number and its reverse is equal then it is a Palindrome Number otherwise not.

# %%
a = int(input("Enter a number :"))
rev = 0
b = a
while b != 0:
    n = b % 10
    rev = rev * 10 + n
    b //= 10
if rev == a:
    print(f"{a} is Palindrome!")
else:
    print(f"{a} is not Palindrome!")
# Out:
# Enter a number : 232
# 232 is Palindrome!
